# %% [markdown]
# <a href="https://colab.research.google.com/github/dhairya-db/dhairya-db/blob/main/Lab_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MATRIX CHAIN MULTIPLICATION Dynamic Programming with table filling.
# Problem Description:
# Find minimum number of scalar multiplications needed to multiply a chain of matrices..

# %% [markdown]
# #Theory
# Cost of multiplying two matrices:
# If A is p×q and B is q×r, cost = p × q × r
#
# Dynamic Programming idea:
# Break problem into smaller subproblems.
# Store results in a table to avoid recomputation.
#
# m[i][j] = minimum cost to multiply Ai to Aj
#
# ## Algorithm
# 1. Take array p[] of size n
# 2. Create table m[n][n]
# 3. Set m[i][i] = 0
# 4. Fill table diagonally
# 5. For each chain length L:
#     Compute m[i][j]
#     Try all possible k between i and j
# 6. Choose minimum cost
# 7. Return m[1][n-1]

# %%
import sys

def matrix_chain_multiplication(p):
    n = len(p)

    m = [[0 for _ in range(n)] for _ in range(n)]

    s = [[0 for _ in range(n)] for _ in range(n)]
    for L in range(2, n):
        for i in range(1, n - L + 1):
            j = i + L - 1
            m[i][j] = sys.maxsize
            for k in range(i, j):

                cost = m[i][k] + m[k+1][j] + p[i-1] * p[k] * p[j]

                if cost < m[i][j]:
                    m[i][j] = cost
                    s[i][j] = k

    return m, s

# %%
def print_optimal_parens(s, i, j):
    if i == j:
        return f"A{i}"
    else:
        return f"({print_optimal_parens(s, i, s[i][j])}{print_optimal_parens(s, s[i][j] + 1, j)})"

# %%
# Input dimensions
p = [10, 30, 5, 60]

table = matrix_chain_multiplication(p)
print("Minimum multiplication cost:", table[0][1][len(p)-1])

print("\nDP Table (Minimum Costs):")
for row in table[0][1:]:

    print(row[1:])
# Out:
# Minimum multiplication cost: 4500
#
# DP Table (Minimum Costs):
# [0, 1500, 4500]
# [0, 0, 9000]
# [0, 0, 0]

# %% [markdown]
# ## Exercise Solution

# %%
# Input dimensions for the exercise
p_exercise = [5, 10, 3, 12, 5, 50, 6]

m_exercise, s_exercise = matrix_chain_multiplication(p_exercise)

print(f"Minimum multiplication cost for p = {p_exercise}: {m_exercise[1][len(p_exercise)-1]}")
print(f"Optimal parenthesization: {print_optimal_parens(s_exercise, 1, len(p_exercise)-1)}")

def naive_multiplication_cost(p_dims):
    if len(p_dims) < 3:
        return 0

    cost = 0
    current_p = list(p_dims)


    cost += current_p[0] * current_p[1] * current_p[2]
    current_dim_rows = current_p[0]
    current_dim_cols = current_p[2]

    for i in range(3, len(current_p)):

        cost += current_dim_rows * current_dim_cols * current_p[i]
        current_dim_cols = current_p[i]

    return cost

def calculate_left_to_right_cost(p):
    cost = 0
    if len(p) <= 2:
        return 0

    for k in range(1, len(p) - 1):
        cost += p[0] * p[k] * p[k+1]
    return cost

naive_cost = calculate_left_to_right_cost(p_exercise)
optimal_cost = m_exercise[1][len(p_exercise)-1]

print(f"Naive (left-to-right) multiplication cost: {naive_cost}")
print(f"Multiplications saved: {naive_cost - optimal_cost}")
# Out:
# Minimum multiplication cost for p = [5, 10, 3, 12, 5, 50, 6]: 2010
# Optimal parenthesization: ((A1A2)((A3A4)(A5A6)))
# Naive (left-to-right) multiplication cost: 3380
# Multiplications saved: 1370

# %% [markdown]
# # Exercise
# 1. Given p = [5, 10, 3, 12, 5, 50, 6]
# 2. Compute minimum cost
# 3. Print optimal parenthesization
# 4. Compare number of multiplications saved
